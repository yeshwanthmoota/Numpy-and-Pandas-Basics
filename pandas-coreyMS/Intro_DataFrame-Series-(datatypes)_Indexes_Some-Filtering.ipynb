# %%
import numpy as np
import pandas as pd

# %%
df.shape
# Out:
# (88883, 85)

# %%
people = {
    "name": ['x', 'y', 'z'],
    "role": ['a', 'b', 'c']
}
print(people['name'])
print(people['role'])
# Out:
# ['x', 'y', 'z']
# ['a', 'b', 'c']

# %%
df_people = pd.DataFrame(people)
df_people.iloc[[0,1], 1]
# Out:
# 0    a
# 1    b
# Name: role, dtype: object

# %%
type(df_people)
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0]
# Out:
# Respondent                                                      1
# MainBranch                 I am a student who is learning to code
# Hobbyist                                                      Yes
# OpenSourcer                                                 Never
# OpenSource      The quality of OSS and closed source software ...
#                                       ...
# Sexuality                                 Straight / Heterosexual
# Ethnicity                                                     NaN
# Dependents                                                     No
# SurveyLength                                Appropriate in length
# SurveyEase                             Neither easy nor difficult
# Name: 0, Length: 85, dtype: object

# %%
df_people.iloc[[1,2],[0,1]]
# Out:
#   name role
# 1    y    b
# 2    z    c

# %%
people = {
    'name': ["John", "Jane", "James", "Jennifer"],
    'email': ["johndoe@gmail.com", "janedoe@gmail.com", "JamesB@gmail.com", "JenniferAnniston@gmail.com"]
}

# %%
people
# Out:
# {'name': ['John', 'Jane', 'James', 'Jennifer'],
#  'email': ['johndoe@gmail.com',
#   'janedoe@gmail.com',
#   'JamesB@gmail.com',
#   'JenniferAnniston@gmail.com']}

# %%
df = pd.DataFrame(people)
df
# Out:
#        name                       email
# 0      John           johndoe@gmail.com
# 1      Jane           janedoe@gmail.com
# 2     James            JamesB@gmail.com
# 3  Jennifer  JenniferAnniston@gmail.com

# %%
df = df.set_index("email")

# %%
df
# Out:
#                                 name
# email
# johndoe@gmail.com               John
# janedoe@gmail.com               Jane
# JamesB@gmail.com               James
# JenniferAnniston@gmail.com  Jennifer

# %%
df
# Out:
#        name                       email
# 0      John           johndoe@gmail.com
# 1      Jane           janedoe@gmail.com
# 2     James            JamesB@gmail.com
# 3  Jennifer  JenniferAnniston@gmail.com

# %%
df.set_index("name")
# Out:
#                                email
# name
# John               johndoe@gmail.com
# Jane               janedoe@gmail.com
# James               JamesB@gmail.com
# Jennifer  JenniferAnniston@gmail.com

# %%
df
# Out:
#        name                       email
# 0      John           johndoe@gmail.com
# 1      Jane           janedoe@gmail.com
# 2     James            JamesB@gmail.com
# 3  Jennifer  JenniferAnniston@gmail.com

# %%
people["name"].append("Yeshwanth")
people["email"].append("YeshwanthM@gmail.com")

# %%
df = pd.DataFrame(people)
df
# Out:
#         name                       email
# 0       John           johndoe@gmail.com
# 1       Jane           janedoe@gmail.com
# 2      James            JamesB@gmail.com
# 3   Jennifer  JenniferAnniston@gmail.com
# 4  Yeshwanth        YeshwanthM@gmail.com

# %%
df_add = pd.DataFrame({"name": ["Siri"], "email": ["siriM@gmail.com"]})
df_add
# Out:
#    name            email
# 0  Siri  siriM@gmail.com

# %%
df
# Out:
#         name                       email
# 0       John           johndoe@gmail.com
# 1       Jane           janedoe@gmail.com
# 2      James            JamesB@gmail.com
# 3   Jennifer  JenniferAnniston@gmail.com
# 4  Yeshwanth        YeshwanthM@gmail.com

# %%
df
# Out:
#         name                       email
# 0       John           johndoe@gmail.com
# 1       Jane           janedoe@gmail.com
# 2      James            JamesB@gmail.com
# 3   Jennifer  JenniferAnniston@gmail.com
# 4  Yeshwanth        YeshwanthM@gmail.com

# %%
df.loc[len(df)] = ["Siri", "siriM@gmail.com"]
df
# Out:
#         name                       email
# 0       John           johndoe@gmail.com
# 1       Jane           janedoe@gmail.com
# 2      James            JamesB@gmail.com
# 3   Jennifer  JenniferAnniston@gmail.com
# 4  Yeshwanth        YeshwanthM@gmail.com
# 5       Siri             siriM@gmail.com

# %%
df = df.set_index("email")
df
# Out:
#                                  name
# email
# johndoe@gmail.com                John
# janedoe@gmail.com                Jane
# JamesB@gmail.com                James
# JenniferAnniston@gmail.com   Jennifer
# YeshwanthM@gmail.com        Yeshwanth
# siriM@gmail.com                  Siri

# %%
df
# Out:
#                                  name
# email
# johndoe@gmail.com                John
# janedoe@gmail.com                Jane
# JamesB@gmail.com                James
# JenniferAnniston@gmail.com   Jennifer
# YeshwanthM@gmail.com        Yeshwanth
# siriM@gmail.com                  Siri

# %%
df["name"]
# Out:
# email
# johndoe@gmail.com                  John
# janedoe@gmail.com                  Jane
# JamesB@gmail.com                  James
# JenniferAnniston@gmail.com     Jennifer
# YeshwanthM@gmail.com          Yeshwanth
# siriM@gmail.com                    Siri
# Name: name, dtype: object

# %%
df.index
# Out:
# Index(['johndoe@gmail.com', 'janedoe@gmail.com', 'JamesB@gmail.com',
#        'JenniferAnniston@gmail.com', 'YeshwanthM@gmail.com',
#        'siriM@gmail.com'],
#       dtype='object', name='email')

# %%
df.loc["JenniferAnniston@gmail.com"]
# Out:
# name    Jennifer
# Name: JenniferAnniston@gmail.com, dtype: object

# %%
df.iloc[3]
# Out:
# name    Jennifer
# Name: JenniferAnniston@gmail.com, dtype: object

# %%
df.loc[["JamesB@gmail.com", "johndoe@gmail.com", "YeshwanthM@gmail.com"], "name"]
# Out:
# email
# JamesB@gmail.com            James
# johndoe@gmail.com            John
# YeshwanthM@gmail.com    Yeshwanth
# Name: name, dtype: object

# %%
df.loc[["JamesB@gmail.com", "johndoe@gmail.com", "YeshwanthM@gmail.com"]]
# Out:
#                            name
# email
# JamesB@gmail.com          James
# johndoe@gmail.com          John
# YeshwanthM@gmail.com  Yeshwanth

# %%
df = df.reset_index()

# %%
df
# Out:
#                         email       name
# 0           johndoe@gmail.com       John
# 1           janedoe@gmail.com       Jane
# 2            JamesB@gmail.com      James
# 3  JenniferAnniston@gmail.com   Jennifer
# 4        YeshwanthM@gmail.com  Yeshwanth
# 5             siriM@gmail.com       Siri

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=88883, step=1)

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.set_index("Respondent")
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df = pd.read_csv("data/survey_results_schema.csv")
schema_df
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema_df.set_index("Column", inplace=True)

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc["Ethnicity"]
# Out:
# QuestionText    Which of the following do you identify as? Ple...
# Name: Ethnicity, dtype: object

# %%
schema_df.loc["Ethnicity", "QuestionText"]
# Out:
# 'Which of the following do you identify as? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
schema_df.sort_index(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 schema_df.sort_index(ascending=False)
#
# NameError: name 'schema_df' is not defined

# %%
people['last'] = ["Doe", "Doe", "Brad", "Anniston"]
people
# Out:
# {'name': ['John', 'Jane', 'James', 'Jennifer'],
#  'email': ['johndoe@gmail.com',
#   'janedoe@gmail.com',
#   'JamesB@gmail.com',
#   'JenniferAnniston@gmail.com'],
#  'last': ['Doe', 'Doe', 'Brad', 'Anniston']}

# %%
df = pd.DataFrame(people)
df
# Out:
#        name                       email      last
# 0      John           johndoe@gmail.com       Doe
# 1      Jane           janedoe@gmail.com       Doe
# 2     James            JamesB@gmail.com      Brad
# 3  Jennifer  JenniferAnniston@gmail.com  Anniston

# %%
type(df["last"] == "Doe")
# Out:
# pandas.core.series.Series

# %%
df.loc[[True, False, True, True], "email"]
# Out:
# 0             johndoe@gmail.com
# 2              JamesB@gmail.com
# 3    JenniferAnniston@gmail.com
# Name: email, dtype: object

# %%
np_arr = np.array([
    [
        [1, 2, 3],
        [4, 5, 6]
    ],
    [
        [4, 5, 6],
        [1, 2, 3]
    ],
    [
        [7, 8, 9],
        [4, 5, 6]
    ]
])
np_arr
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[4, 5, 6],
#         [1, 2, 3]],
#
#        [[7, 8, 9],
#         [4, 5, 6]]])

# %%
np_arr.shape
# Out:
# (2, 2, 3)

# %%
np_arr.ndim
# Out:
# 3

# %%
np_arr.size
# Out:
# 12

# %%
len(np_arr)
# Out:
# 3

# %%
filt = (df["last"] == "Doe") & (df["name"] == "John")
df.loc[~filt]
# Out:
#        name                       email      last
# 1      Jane           janedoe@gmail.com       Doe
# 2     James            JamesB@gmail.com      Brad
# 3  Jennifer  JenniferAnniston@gmail.com  Anniston

# %%
filt = (df["last"] == "Doe") | (df["name"] == "John")
df.loc[~filt]
# Out:
#        name                       email      last
# 2     James            JamesB@gmail.com      Brad
# 3  Jennifer  JenniferAnniston@gmail.com  Anniston
