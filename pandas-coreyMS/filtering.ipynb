# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
print(df.shape, schema_df.shape)
# Out:
# (88883, 85) (85, 2)

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
schema_df
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
filt = []
for text in schema_df["QuestionText"]:
    if 'salary' in text.lower():
        filt.append(True)
    else:
        filt.append(False)

# %%
filt
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
schema_df.loc[filt]
# Out:
#            Column  \
# 29      CompTotal
# 31  ConvertedComp
#
#                                                                                                                                                                                                                                                                                                                                         QuestionText
# 29  What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in `CurrencySymbol`? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.
# ...

# %%
def finder(searchText):
    filt = []
    for text in schema_df["QuestionText"]:
        if searchText in text.lower():
            filt.append(True)
        else:
            filt.append(False)
    return schema_df.loc[filt]
finder("salary")
# Out:
#            Column  \
# 29      CompTotal
# 31  ConvertedComp
#
#                                                                                                                                                                                                                                                                                                                                         QuestionText
# 29  What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in `CurrencySymbol`? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.
# ...

# %%
high_salary = (df["ConvertedComp"] > 70000)
df[high_salary]
# Out:
#        Respondent  \
# 5               6
# 8               9
# 12             13
# 15             16
# 21             22
# ...           ...
# 88323       88876
# 88324       88877
# 88325       88878
# 88326       88879
# 88329       88882
#
#                                                                           MainBranch  \
# 5      I am not primarily a developer, but I write code sometimes as part of my work
# 8                                                     I am a developer by profession
# 12                                                    I am a developer by profession
# 15                                                    I am a developer by profession
# 21                                                    I am a developer by profession
# ...                                                                              ...
# 88323                                                 I am a developer by profession
# ...

# %%
finder("language")
# Out:
#                     Column  \
# 43      LanguageWorkedWith
# 44  LanguageDesireNextYear
#
#                                                                                                                                                                                                                                                                                             QuestionText
# 43  Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# 44  Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)

# %%
df1 = df.loc[high_salary, ["Country", "LanguageWorkedWith", "ConvertedComp"]]
df1
# Out:
#               Country  \
# 5              Canada
# 8         New Zealand
# 12      United States
# 15     United Kingdom
# 21      United States
# ...               ...
# 88323   United States
# 88324   United States
# 88325   United States
# 88326         Finland
# 88329     Netherlands
#
#                                                                                        LanguageWorkedWith  \
# 5                                                                                              Java;R;SQL
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript;WebAssembly;Other(s):
# 12                                           Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 15                                            Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;TypeScript;VBA
# 21                               Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# ...

# %%
countries = ["United States", "India", "Germany", "United Kingdom", "Canada"]
### isin() function is a python-pandas function to check if the value is in DataFrame or not
filt1 = df1['Country'].isin(countries)
df1.loc[filt1]
# Out:
#               Country  \
# 5              Canada
# 12      United States
# 15     United Kingdom
# 21      United States
# 25      United States
# ...               ...
# 88320          Canada
# 88321   United States
# 88323   United States
# 88324   United States
# 88325   United States
#
#                                                                               LanguageWorkedWith  \
# 5                                                                                     Java;R;SQL
# 12                                  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 15                                   Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;TypeScript;VBA
# 21                      Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# 25     Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScript;PHP;Python;Ruby;SQL;Swift;TypeScript;VBA
# ...                                                                                          ...
# ...

# %%
### .str.contains is a python-pandas function to check if a substring is present inside a main string
filt2 = (df1["LanguageWorkedWith"].str.contains("Python", na=False)) #& (df1['Country'].isin(countries))
df1.loc[filt2]
# Out:
#              Country  \
# 8        New Zealand
# 21     United States
# 25     United States
# 31     United States
# 44     United States
# ...              ...
# 88320         Canada
# 88321  United States
# 88323  United States
# 88326        Finland
# 88329    Netherlands
#
#                                                                                        LanguageWorkedWith  \
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript;WebAssembly;Other(s):
# 21                               Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;Python;Ruby;SQL;TypeScript
# 25              Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScript;PHP;Python;Ruby;SQL;Swift;TypeScript;VBA
# 31                                                   Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;Python
# 44                                                                                                 Python
# ...
